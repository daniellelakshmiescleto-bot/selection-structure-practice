# %% [markdown]
# <a href="https://colab.research.google.com/github/daniellelakshmiescleto-bot/selection-structure-practice/blob/main/selection_structure_practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Exercise 1

number = int(input("Enter a number: "))

# Determines and displays whether a number is even or odd

if number % 2 == 0:
  print(f"{number} is even.")

else:
  print(f"{number} is odd.")
# Out:
# Enter a number: 67
# 67 is odd.
